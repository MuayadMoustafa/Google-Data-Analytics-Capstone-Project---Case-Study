# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('final_tripdata.csv')

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  Southport Ave & Clybourn Ave            307  41.961406 -87.676169
# 1     Milwaukee Ave & Grand Ave          13033  41.878261 -87.641155
# 2    Kedzie Ave & Milwaukee Ave            260  41.949399 -87.654529
# 3         Wells St & Concord Ln            289  41.881900 -87.648800
# 4           Morgan St & Lake St   TA1306000015  41.889899 -87.671473
#
#      end_lat    end_lng member_casual  day_week_start  duration  distance
# 0  41.920771 -87.663712        casual             4.0    1824.0  42501.53
# 1  41.891495 -87.648179        member             3.0     619.0  14982.48
# 2  41.929567 -87.707857        casual             7.0   10808.0  56896.25
# 3  41.912100 -87.634700        member             7.0    1892.0  33329.42
# 4  41.885483 -87.652305        member             4.0     903.0  19670.18

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# day_week_start        float64
# duration              float64
# distance              float64
# dtype: object

# %%
df.shape
# Out:
# (5515094, 16)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  Southport Ave & Clybourn Ave            307  41.961406 -87.676169
# 1     Milwaukee Ave & Grand Ave          13033  41.878261 -87.641155
# 2    Kedzie Ave & Milwaukee Ave            260  41.949399 -87.654529
# 3         Wells St & Concord Ln            289  41.881900 -87.648800
# 4           Morgan St & Lake St   TA1306000015  41.889899 -87.671473
#
#      end_lat    end_lng member_casual  day_week_start  duration  distance
# 0  41.920771 -87.663712        casual             4.0    1824.0  42501.53
# 1  41.891495 -87.648179        member             3.0     619.0  14982.48
# 2  41.929567 -87.707857        casual             7.0   10808.0  56896.25
# 3  41.912100 -87.634700        member             7.0    1892.0  33329.42
# 4  41.885483 -87.652305        member             4.0     903.0  19670.18

# %%
df[df['duration'] <= 0]
# Out:
#                   ride_id  rideable_type           started_at  \
# 311      0003D0AA1F7CEAC8    docked_bike  2020-08-23 12:10:56
# 2027     00183B358D2A454A    docked_bike  2020-06-07 14:28:51
# 4872     003A706B9EDAF788    docked_bike  2020-07-16 19:21:11
# 5071     003CB4B59125E2F8    docked_bike  2020-08-22 14:35:01
# 5640     0043859A4D6DC837    docked_bike  2020-06-23 18:12:25
# ...                   ...            ...                  ...
# 5513940  FFF3424C0EF50E94    docked_bike  2020-10-09 17:08:53
# 5514326  FFF73C3D40D75146    docked_bike  2020-10-02 08:02:59
# 5514414  FFF850D8D4C3EFC9  electric_bike  2020-10-16 16:45:00
# 5514544  FFF9CB518645F387    docked_bike  2020-11-09 18:54:16
# 5515018  FFFF33C12C91FAC9    docked_bike  2020-03-12 09:04:58
#
#                     ended_at              start_station_name start_station_id  \
# 311      2020-08-23 12:10:40          Clark St & Chicago Ave              337
# 2027     2020-06-07 14:28:44       Clark St & Wellington Ave              156
# 4872     2020-07-16 19:21:02           Ritchie Ct & Banks St              180
# 5071     2020-08-22 14:34:50      Wilton Ave & Diversey Pkwy               13
# 5640     2020-06-23 18:12:25                  Burnham Harbor                4
# ...                      ...                             ...              ...
# 5513940  2020-10-09 17:06:14           Green St & Madison St              198
# 5514326  2020-10-02 08:02:04  Southport Ave & Wrightwood Ave              190
# 5514414  2020-10-16 15:58:41      Clifton Ave & Armitage Ave              223
# 5514544  2020-11-09 18:53:48             Wabash Ave & 9th St              321
# 5515018  2020-03-12 09:04:45                           HQ QR              675
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 311         Noble St & Milwaukee Ave             29  41.896750 -87.630890
# 2027       Milwaukee Ave & Grand Ave             84  41.936496 -87.647538
# 4872        LaSalle St & Illinois St            181  41.906866 -87.626217
# 5071     Lake Shore Dr & Belmont Ave            334  41.932418 -87.652705
# 5640     Field Blvd & South Water St              7  41.856268 -87.613348
# ...                              ...            ...        ...        ...
# 5513940     Kingsbury St & Kinzie St            133  41.881892 -87.648789
# 5514326  Southport Ave & Belmont Ave            154  41.928773 -87.663913
# 5514414    Larrabee St & Webster Ave            144  41.918163 -87.657064
# 5514544        Indiana Ave & 26th St            147  41.870769 -87.625734
# 5515018                        HQ QR            675  41.889900 -87.680300
#
#            end_lat    end_lng member_casual  day_week_start  duration  \
# 311      41.900680 -87.662600        casual             1.0     -16.0
# 2027     41.891578 -87.648384        casual             1.0      -7.0
# 4872     41.890762 -87.631697        member             5.0      -9.0
# 5071     41.940775 -87.639192        member             7.0     -51.0
# 5640     41.886349 -87.617517        member             3.0       0.0
# ...            ...        ...           ...             ...       ...
# 5513940  41.889177 -87.638506        member             6.0    -239.0
# 5514326  41.938943 -87.663866        casual             6.0     -55.0
# 5514414  41.921848 -87.644057        casual             6.0   -8659.0
# 5514544  41.845687 -87.622481        member             2.0     -68.0
# 5515018  41.889900 -87.680300        casual             5.0     -13.0
#
#          distance
# 311      31952.61
# 2027     44925.97
# 4872     17010.86
# 5071     15888.38
# 5640     30368.46
# ...           ...
# 5513940  12602.11
# 5514326  10170.11
# 5514414  13518.55
# 5514544  25292.07
# 5515018      0.00
#
# [11306 rows x 16 columns]

# %%
df.drop(df.index[df['duration'] <= 0],inplace =True)

# %%
df[df['duration'] <= 0]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, day_week_start, duration, distance]
# Index: []

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  Southport Ave & Clybourn Ave            307  41.961406 -87.676169
# 1     Milwaukee Ave & Grand Ave          13033  41.878261 -87.641155
# 2    Kedzie Ave & Milwaukee Ave            260  41.949399 -87.654529
# 3         Wells St & Concord Ln            289  41.881900 -87.648800
# 4           Morgan St & Lake St   TA1306000015  41.889899 -87.671473
#
#      end_lat    end_lng member_casual  day_week_start  duration  distance
# 0  41.920771 -87.663712        casual             4.0    1824.0  42501.53
# 1  41.891495 -87.648179        member             3.0     619.0  14982.48
# 2  41.929567 -87.707857        casual             7.0   10808.0  56896.25
# 3  41.912100 -87.634700        member             7.0    1892.0  33329.42
# 4  41.885483 -87.652305        member             4.0     903.0  19670.18

# %%
df[df['distance']<0]
# Out:
#                      ride_id rideable_type           started_at  \
# 299         0003A9FB01F7FD45   docked_bike  2020-08-16 13:25:56
# 963         000BB7D9D7A07F05  classic_bike  2021-05-23 02:10:46
# 1167        000E0BF00DF3C020  classic_bike  2021-04-09 18:17:43
# 1453     0011A31EF3CA864C_12   docked_bike  2020-12-02 15:05:38
# 1510        00126450B12A886B  classic_bike  2021-05-21 18:07:54
# ...                      ...           ...                  ...
# 5511589     FFD707721D7C0824   docked_bike  2020-07-20 19:46:23
# 5511725     FFD892DDA304E510  classic_bike  2021-03-09 02:27:36
# 5513820     FFF1DAE49435E6EE   docked_bike  2020-10-30 04:47:38
# 5514100     FFF4D9E9B8712894   docked_bike  2020-11-25 07:41:56
# 5514357     FFF7A4A2A4F4FA32   docked_bike  2020-11-03 10:05:46
#
#                     ended_at                       start_station_name  \
# 299      2020-08-16 13:33:28           Lake Shore Dr & Wellington Ave
# 963      2021-05-23 02:10:59                 Halsted St & Dickens Ave
# 1167     2021-04-10 19:17:37                Latrobe Ave & Chicago Ave
# 1453     2020-12-03 16:05:29               Sheridan Rd & Columbia Ave
# 1510     2021-05-22 19:07:44                    Green St & Madison St
# ...                      ...                                      ...
# 5511589  2020-07-20 20:09:01                      Theater on the Lake
# 5511725  2021-03-10 03:27:28                    Rush St & Superior St
# 5513820  2020-10-30 11:02:12                Washtenaw Ave & Ogden Ave
# 5514100  2020-11-25 08:29:43  Wolcott (Ravenswood) Ave & Montrose Ave
# 5514357  2020-11-03 10:21:16                  Clark St & Armitage Ave
#
#         start_station_id end_station_name end_station_id  start_lat  \
# 299                  157              NaN            NaN  41.936688
# 963                13192              NaN            NaN  41.919936
# 1167                 642              NaN            NaN  41.894745
# 1453                 660              NaN            NaN  42.004583
# 1510        TA1307000120              NaN            NaN  41.881892
# ...                  ...              ...            ...        ...
# 5511589              177              NaN            NaN  41.926277
# 5511725            15530              NaN            NaN  41.895765
# 5513820              437              NaN            NaN  41.861930
# 5514100              238              NaN            NaN  41.961406
# 5514357               94              NaN            NaN  41.918306
#
#          start_lng  end_lat  end_lng member_casual  day_week_start   duration  \
# 299     -87.636829      0.0      0.0        member             1.0      772.0
# 963     -87.648830      0.0      0.0        casual             1.0       13.0
# 1167    -87.756895      0.0      0.0        casual             6.0  1009994.0
# 1453    -87.661406      0.0      0.0        member             4.0  1009991.0
# 1510    -87.648789      0.0      0.0        member             6.0  1009990.0
# ...            ...      ...      ...           ...             ...        ...
# 5511589 -87.630834      0.0      0.0        casual             2.0     6278.0
# 5511725 -87.625908      0.0      0.0        casual             3.0  1009992.0
# 5513820 -87.693450      0.0      0.0        member             6.0    65474.0
# 5514100 -87.676169      0.0      0.0        member             4.0     8787.0
# 5514357 -87.636282      0.0      0.0        member             3.0     1570.0
#
#          distance
# 299          -1.0
# 963          -1.0
# 1167         -1.0
# 1453         -1.0
# 1510         -1.0
# ...           ...
# 5511589      -1.0
# 5511725      -1.0
# 5513820      -1.0
# 5514100      -1.0
# 5514357      -1.0
#
# [6113 rows x 16 columns]

# %%
df.drop(df.index[df['distance'] <= 0],inplace =True)

# %%
df[df['distance']<0]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, day_week_start, duration, distance]
# Index: []

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  Southport Ave & Clybourn Ave            307  41.961406 -87.676169
# 1     Milwaukee Ave & Grand Ave          13033  41.878261 -87.641155
# 2    Kedzie Ave & Milwaukee Ave            260  41.949399 -87.654529
# 3         Wells St & Concord Ln            289  41.881900 -87.648800
# 4           Morgan St & Lake St   TA1306000015  41.889899 -87.671473
#
#      end_lat    end_lng member_casual  day_week_start  duration  distance
# 0  41.920771 -87.663712        casual             4.0    1824.0  42501.53
# 1  41.891495 -87.648179        member             3.0     619.0  14982.48
# 2  41.929567 -87.707857        casual             7.0   10808.0  56896.25
# 3  41.912100 -87.634700        member             7.0    1892.0  33329.42
# 4  41.885483 -87.652305        member             4.0     903.0  19670.18

# %%
df.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              1
# started_at                 1
# ended_at                   1
# start_station_name    241975
# start_station_id      242532
# end_station_name      269491
# end_station_id        269890
# start_lat                  1
# start_lng                  1
# end_lat                    1
# end_lng                    1
# member_casual              1
# day_week_start             1
# duration                   1
# distance                   1
# dtype: int64

# %%
df = df.dropna()

# %%
 df.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# day_week_start        0
# duration              0
# distance              0
# dtype: int64

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  Southport Ave & Clybourn Ave            307  41.961406 -87.676169
# 1     Milwaukee Ave & Grand Ave          13033  41.878261 -87.641155
# 2    Kedzie Ave & Milwaukee Ave            260  41.949399 -87.654529
# 3         Wells St & Concord Ln            289  41.881900 -87.648800
# 4           Morgan St & Lake St   TA1306000015  41.889899 -87.671473
#
#      end_lat    end_lng member_casual  day_week_start  duration  distance
# 0  41.920771 -87.663712        casual             4.0    1824.0  42501.53
# 1  41.891495 -87.648179        member             3.0     619.0  14982.48
# 2  41.929567 -87.707857        casual             7.0   10808.0  56896.25
# 3  41.912100 -87.634700        member             7.0    1892.0  33329.42
# 4  41.885483 -87.652305        member             4.0     903.0  19670.18

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, day_week_start, duration, distance]
# Index: []

# %%
df['day_week_start'].replace({1.0:'sunday',2.0:'monday',3.0:'tuesday',4.0:'wednesday',5.0:'thursday',6.0:'friday',7.0:'saturday'},inplace = True)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  Southport Ave & Clybourn Ave            307  41.961406 -87.676169
# 1     Milwaukee Ave & Grand Ave          13033  41.878261 -87.641155
# 2    Kedzie Ave & Milwaukee Ave            260  41.949399 -87.654529
# 3         Wells St & Concord Ln            289  41.881900 -87.648800
# 4           Morgan St & Lake St   TA1306000015  41.889899 -87.671473
#
#      end_lat    end_lng member_casual day_week_start  duration  distance
# 0  41.920771 -87.663712        casual      wednesday    1824.0  42501.53
# 1  41.891495 -87.648179        member        tuesday     619.0  14982.48
# 2  41.929567 -87.707857        casual       saturday   10808.0  56896.25
# 3  41.912100 -87.634700        member       saturday    1892.0  33329.42
# 4  41.885483 -87.652305        member      wednesday     903.0  19670.18

# %%
df = df.drop(['start_lat','start_lng','end_lat','end_lng'],axis = 1)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
# 2    Kedzie Ave & Milwaukee Ave            260        casual       saturday
# 3         Wells St & Concord Ln            289        member       saturday
# 4           Morgan St & Lake St   TA1306000015        member      wednesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48
# 2   10808.0  56896.25
# 3    1892.0  33329.42
# 4     903.0  19670.18

# %%
df_member = df
df_causal = df
df_both = df

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
# 2    Kedzie Ave & Milwaukee Ave            260        casual       saturday
# 3         Wells St & Concord Ln            289        member       saturday
# 4           Morgan St & Lake St   TA1306000015        member      wednesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48
# 2   10808.0  56896.25
# 3    1892.0  33329.42
# 4     903.0  19670.18

# %%
df.describe()
# Out:
#            duration      distance
# count  4.685565e+06  4.685565e+06
# mean   5.644010e+04  2.369751e+04
# std    1.538609e+07  1.876522e+04
# min    1.000000e+00  1.000000e-02
# 25%    8.020000e+02  1.074132e+04
# 50%    1.586000e+03  1.844213e+04
# 75%    5.121000e+03  3.146654e+04
# max    8.875942e+09  4.494231e+05

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
# 4  00001A81D056B01B   classic_bike  2021-04-14 08:10:11  2021-04-14 08:19:14
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
# 3                    Green St & Madison St              198
# 4                     Wood St & Hubbard St            13432
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
# 2    Kedzie Ave & Milwaukee Ave            260        casual       saturday
# 3         Wells St & Concord Ln            289        member       saturday
# 4           Morgan St & Lake St   TA1306000015        member      wednesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48
# 2   10808.0  56896.25
# 3    1892.0  33329.42
# 4     903.0  19670.18

# %%
df['member_casual'].value_counts()
# Out:
# member    2917439
# casual    1768126
# Name: member_casual, dtype: int64

# %%
#there are 2,917,439 members- 62.26%
#there are 1,768,126 casual riders-37.74%

# %%
df.head(3)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
# 2    Kedzie Ave & Milwaukee Ave            260        casual       saturday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48
# 2   10808.0  56896.25

# %%
df['distance'].mean()
# Out:
# 23697.50758100466

# %%
df['distance'].max()
# Out:
# 449423.09

# %%
df['day_week_start'].mode()
# Out:
# 0    saturday
# Name: day_week_start, dtype: object

# %%
df.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48

# %%
df['start_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave            53336
# Clark St & Elm St                  43893
# Lake Shore Dr & North Blvd         38252
# Lake Shore Dr & Monroe St          38184
# Wells St & Concord Ln              37816
#                                    ...
# Stewart Ave & 63rd St (*)              3
# HQ QR                                  1
# N Clark St & W Elm St                  1
# N Hampden Ct & W Diversey Ave          1
# Lyft Driver Center Private Rack        1
# Name: start_station_name, Length: 715, dtype: int64

# %%
# From above we can conclude that :-
# 'Streeter Dr & Grand Ave'  is the most visited station,
# 53336 riders have started their rides from this station

# %%
df['end_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave          56545
# Clark St & Elm St                43956
# Lake Shore Dr & North Blvd       40798
# Theater on the Lake              39712
# Wells St & Concord Ln            38637
#                                  ...
# N Clark St & W Elm St                2
# N Damen Ave & W Wabansia St          2
# Avenue L & 114th St                  1
# HQ QR                                1
# N Hampden Ct & W Diversey Ave        1
# Name: end_station_name, Length: 716, dtype: int64

# %%
# From above we can conclude that :-
# 'Streeter Dr & Grand Ave'  is the most visited station,
# 53336 riders have ended their rides from this station

# %%
df.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48

# %%
df['rideable_type'].value_counts()
# Out:
# docked_bike      2776356
# classic_bike     1205865
# electric_bike     703344
# Name: rideable_type, dtype: int64

# %%
# From above result we can conclude that :-
# 'docked_bike' is the most preferable rideable_type.

# %%
df.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48

# %%
df['day_week_start'].value_counts()
# Out:
# saturday     833136
# sunday       706254
# friday       686002
# wednesday    641247
# thursday     621602
# tuesday      615493
# monday       581831
# Name: day_week_start, dtype: int64

# %%
# From above result we can conclude that :-
# 'saturday' is the busiest day of the week throught out the year.

# %%
df.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  000001004784CD35    docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48

# %%
df_member = df[df['member_casual'] == 'member']

# %%
df_casual = df[df['member_casual'] == 'casual']

# %%
df_member['distance'].mean()
# Out:
# 22985.715532444712

# %%
df_member.describe()
# Out:
#            duration      distance
# count  2.917439e+06  2.917439e+06
# mean   2.552066e+04  2.298572e+04
# std    1.163140e+07  1.781781e+04
# min    1.000000e+00  1.000000e-02
# 25%    6.750000e+02  1.037690e+04
# 50%    1.224000e+03  1.777553e+04
# 75%    3.271000e+03  3.051190e+04
# max    8.869776e+09  4.494231e+05

# %%
df_casual.describe()
# Out:
#            duration      distance
# count  1.768126e+06  1.768126e+06
# mean   1.074577e+05  2.487198e+04
# std    2.010248e+07  2.017689e+04
# min    1.000000e+00  1.000000e-02
# 25%    1.196000e+03  1.149538e+04
# 50%    2.543000e+03  1.971238e+04
# 75%    6.790000e+03  3.296709e+04
# max    8.875942e+09  3.042953e+05

# %%
df_member.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 1  000002EBE159AE82  electric_bike  2021-06-22 17:25:15  2021-06-22 17:31:34
# 3  0000127970C84F62    docked_bike  2020-05-30 06:36:36  2020-05-30 06:55:28
#
#           start_station_name start_station_id           end_station_name  \
# 1  Clinton St & Jackson Blvd              638  Milwaukee Ave & Grand Ave
# 3      Green St & Madison St              198      Wells St & Concord Ln
#
#   end_station_id member_casual day_week_start  duration  distance
# 1          13033        member        tuesday     619.0  14982.48
# 3            289        member       saturday    1892.0  33329.42

# %%
df_casual.head(2)
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  000001004784CD35   docked_bike  2020-07-22 15:38:23  2020-07-22 15:56:47
# 2  00000550C665101A   docked_bike  2020-06-06 15:20:01  2020-06-06 16:28:09
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 2             Sheffield Ave & Waveland Ave              114
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 2    Kedzie Ave & Milwaukee Ave            260        casual       saturday
#
#    duration  distance
# 0    1824.0  42501.53
# 2   10808.0  56896.25

# %%
df_member['rideable_type'].value_counts()
#bikes riden by members only
#docked_bike was 1,727,733 members -59.22%
#classic_bike was 792,599 members - 27.17%
#electric_bike was 397,107 members - 13.61%
# Out:
# docked_bike      1727733
# classic_bike      792599
# electric_bike     397107
# Name: rideable_type, dtype: int64

# %%
df_casual['rideable_type'].value_counts()
#bikes riden by casual only
#docked_bike was 1,048,623 Casual -59.31%
#classic_bike was 413,266 Casual - 23.37%
#electric_bike was 306,237 Casual - 17.32%
# Out:
# docked_bike      1048623
# classic_bike      413266
# electric_bike     306237
# Name: rideable_type, dtype: int64

# %%
df_member['start_station_name'].value_counts()
# Out:
# Clark St & Elm St                  28492
# Kingsbury St & Kinzie St           24650
# Wells St & Concord Ln              23030
# Dearborn St & Erie St              22423
# St. Clair St & Erie St             22228
#                                    ...
# Avenue O & 118th St                    1
# Vernon Ave & 107th St                  1
# Elizabeth St & 92nd St                 1
# Ashland Ave & 73rd St                  1
# Lyft Driver Center Private Rack        1
# Name: start_station_name, Length: 706, dtype: int64

# %%
df_casual['start_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave       39555
# Millennium Park               26701
# Lake Shore Dr & Monroe St     25950
# Michigan Ave & Oak St         20887
# Lake Shore Dr & North Blvd    19380
#                               ...
# Hampden Ct & Diversey Ave         3
# W 103rd St & S Avers Ave          3
# HQ QR                             1
# N Clark St & W Elm St             1
# Stewart Ave & 63rd St (*)         1
# Name: start_station_name, Length: 712, dtype: int64

# %%
df_member['end_station_name'].value_counts()
# Out:
# Clark St & Elm St           29235
# Kingsbury St & Kinzie St    24892
# St. Clair St & Erie St      23893
# Wells St & Concord Ln       23554
# Dearborn St & Erie St       23346
#                             ...
# Ashland Ave & 73rd St           1
# Yates Blvd & 93rd St            1
# N Clark St & W Elm St           1
# Avenue O & 134th St             1
# Loomis St & 89th St             1
# Name: end_station_name, Length: 709, dtype: int64

# %%
df_casual['end_station_name'].value_counts()
# Out:
# Streeter Dr & Grand Ave                             43370
# Millennium Park                                     28405
# Lake Shore Dr & Monroe St                           24336
# Lake Shore Dr & North Blvd                          22059
# Michigan Ave & Oak St                               22038
#                                                     ...
# Woodlawn & 103rd - Olive Harvey Vaccination Site        3
# Eggleston Ave & 69th St (*)                             2
# Avenue L & 114th St                                     1
# N Clark St & W Elm St                                   1
# N Hampden Ct & W Diversey Ave                           1
# Name: end_station_name, Length: 714, dtype: int64

# %%
df_member['day_week_start'].value_counts()
# Out:
# wednesday    447619
# tuesday      431542
# friday       430723
# thursday     426599
# saturday     419125
# monday       396422
# sunday       365409
# Name: day_week_start, dtype: int64

# %%
df_casual['day_week_start'].value_counts()
# Out:
# saturday     414011
# sunday       340845
# friday       255279
# thursday     195003
# wednesday    193628
# monday       185409
# tuesday      183951
# Name: day_week_start, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
from datetime import date
df['started_at'] = pd.to_datetime(df['started_at']).dt.normalize()

# %%
df.head(3)
# Out:
#             ride_id  rideable_type started_at             ended_at  \
# 0  000001004784CD35    docked_bike 2020-07-22  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike 2021-06-22  2021-06-22 17:31:34
# 2  00000550C665101A    docked_bike 2020-06-06  2020-06-06 16:28:09
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
# 2             Sheffield Ave & Waveland Ave              114
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
# 2    Kedzie Ave & Milwaukee Ave            260        casual       saturday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48
# 2   10808.0  56896.25

# %%
by_date = pd.Series(df['started_at']).value_counts().sort_index()
by_date.index = pd.DatetimeIndex(by_date.index)
df_date = by_date.rename_axis('date').reset_index(name='counts')
df_date
# Out:
#           date  counts
# 0   2020-01-01    1979
# 1   2020-01-02    6300
# 2   2020-01-03    5753
# 3   2020-01-04    3083
# 4   2020-01-05    2879
# ..         ...     ...
# 540 2021-06-26   11138
# 541 2021-06-27   22521
# 542 2021-06-28   12717
# 543 2021-06-29   13867
# 544 2021-06-30   15008
#
# [545 rows x 2 columns]

# %%
fig= plt.figure()
ax = fig.add_axes([0,0,4,4])
ax.barh(df_date['date'],df_date['counts'])
plt.show()

# %%
by_days = pd.Series(df['day_week_start']).value_counts().sort_index()
by_days.index = pd.Index(by_days.index)
dff_days = by_days.rename_axis('days').reset_index(name='counts')
dff_days
# Out:
#         days  counts
# 0     friday  686002
# 1     monday  581831
# 2   saturday  833136
# 3     sunday  706254
# 4   thursday  621602
# 5    tuesday  615493
# 6  wednesday  641247

# %%
plt.pie(dff_days['counts'],labels=dff_days['days'],autopct='%1.1f%%')
plt.title('Members and Casual')
plt.show()

# %%
by_days = pd.Series(df_member['day_week_start']).value_counts().sort_index()
by_days.index = pd.Index(by_days.index)
df_member_days = by_days.rename_axis('days').reset_index(name='counts')
df_member_days
# Out:
#         days  counts
# 0     friday  430723
# 1     monday  396422
# 2   saturday  419125
# 3     sunday  365409
# 4   thursday  426599
# 5    tuesday  431542
# 6  wednesday  447619

# %%
plt.pie(df_member_days['counts'],labels=df_member_days['days'],autopct='%1.1f%%')
plt.title('Members')
plt.show()

# %%
by_days = pd.Series(df_causal['day_week_start']).value_counts().sort_index()
by_days.index = pd.Index(by_days.index)
df_causal_days = by_days.rename_axis('days').reset_index(name='counts')
df_causal_days
# Out:
#         days  counts
# 0     friday  686002
# 1     monday  581831
# 2   saturday  833136
# 3     sunday  706254
# 4   thursday  621602
# 5    tuesday  615493
# 6  wednesday  641247

# %%
plt.pie(df_causal_days['counts'],labels=df_causal_days['days'],autopct='%1.1f%%')
plt.title('Casual')
plt.show()

# %%
df.head(2)
# Out:
#             ride_id  rideable_type started_at             ended_at  \
# 0  000001004784CD35    docked_bike 2020-07-22  2020-07-22 15:56:47
# 1  000002EBE159AE82  electric_bike 2021-06-22  2021-06-22 17:31:34
#
#                         start_station_name start_station_id  \
# 0  Wolcott (Ravenswood) Ave & Montrose Ave              238
# 1                Clinton St & Jackson Blvd              638
#
#                end_station_name end_station_id member_casual day_week_start  \
# 0  Southport Ave & Clybourn Ave            307        casual      wednesday
# 1     Milwaukee Ave & Grand Ave          13033        member        tuesday
#
#    duration  distance
# 0    1824.0  42501.53
# 1     619.0  14982.48

# %%
df1 = pd.Series(df['rideable_type'].value_counts().sort_index())
df1.index = pd.Index(df1.index)
df1 = df1.rename_axis('rideable_type').reset_index(name = 'counts')
df1
# Out:
#    rideable_type   counts
# 0   classic_bike  1205865
# 1    docked_bike  2776356
# 2  electric_bike   703344

# %%
plt.pie(df1['counts'],labels = df1['rideable_type'], autopct='%1.1f%%')
plt.title('rideable_types for both member and casual')
plt.show()

# %%
df2 = pd.Series(df_member['rideable_type'].value_counts())
df2.index = pd.Index(df2.index)
df2 = df2.rename_axis('rideable_type').reset_index(name = 'counts')
df2
# Out:
#    rideable_type   counts
# 0    docked_bike  1727733
# 1   classic_bike   792599
# 2  electric_bike   397107

# %%
plt.pie(df2['counts'],labels = df2['rideable_type'],autopct ='%1.1f%%' )
plt.show()

# %%
df3 = pd.Series(df_casual['rideable_type'].value_counts())
df3.index = pd.Index(df3.index)
df3 = df3.rename_axis('rideable_type').reset_index(name = 'counts')
df3
# Out:
#    rideable_type   counts
# 0    docked_bike  1048623
# 1   classic_bike   413266
# 2  electric_bike   306237

# %%
plt.pie(df3['counts'],labels = df3['rideable_type'],autopct ='%1.1f%%' )
plt.show()
